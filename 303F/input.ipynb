# %%
# Importing libraries
import pandas as pd

# %%
# 투입량 Loading
INPUT_WT = pd.read_csv('input_303F.csv', encoding='cp949')
INPUT_WT.head()
# Out:
#        년월 HEAT_NO      LOT_NO  공정코드  구분 공장명 주조구분    재료코드 강종그룹    강종코드  ...  \
# 0  202308  S54745  B360553701  9Y01  압연  산세    T  7730.0  SSH  SSH034  ...
# 1  202308  S54745  B360553901  9Y01  압연  산세    T  7730.0  SSH  SSH034  ...
# 2  202302  S52717  B310559703  9Y01  압연  산세    T  7730.0  SSH  SSH034  ...
# 3  202302  S52717  B310559702  9Y01  압연  산세    T  7730.0  SSH  SSH034  ...
# 4  202302  S52717  B310559701  9Y01  압연  산세    T  7730.0  SSH  SSH034  ...
#
#   STRAND_SEQ       주조완료일 주여구분 지시GR종류  생산GR종류 생산GR공정     제강검사완료일         작업일  \
# 0        NaN  2023-06-26    1      A       A   8301  2023-06-27  2023-10-04
# 1        NaN  2023-06-26    1      A       A   8301  2023-06-27  2023-10-04
# 2        NaN  2023-01-02    1      A       A   8301  2023-01-04  2023-02-20
# 3        NaN  2023-01-02    1      A       A   8301  2023-01-04  2023-02-20
# 4        NaN  2023-01-02    1      A       A   8301  2023-01-04  2023-02-20
#
#   강관소재여부 주설비구분
# 0      N     C
# 1      N     C
# 2      N     W
# 3      N     W
# 4      N     W
#
# [5 rows x 58 columns]

# %%
# 중강종 파생변수 생성코드
INPUT_WT['중강종'] = INPUT_WT['강종그룹'].str[0:2]
# STEEL_GROUP_L는 Steel Grade 컬럼 앞에 배치
position = INPUT_WT.columns.get_loc('강종그룹')
INPUT_WT.insert(position, '중강종', INPUT_WT.pop('중강종'))
INPUT_WT.head()
#print(INPUT_WT['중강종'])
# Out:
#        년월 HEAT_NO      LOT_NO  공정코드  구분 공장명 주조구분    재료코드 중강종 강종그룹  ...  \
# 0  202308  S54745  B360553701  9Y01  압연  산세    T  7730.0  SS  SSH  ...
# 1  202308  S54745  B360553901  9Y01  압연  산세    T  7730.0  SS  SSH  ...
# 2  202302  S52717  B310559703  9Y01  압연  산세    T  7730.0  SS  SSH  ...
# 3  202302  S52717  B310559702  9Y01  압연  산세    T  7730.0  SS  SSH  ...
# 4  202302  S52717  B310559701  9Y01  압연  산세    T  7730.0  SS  SSH  ...
#
#   STRAND_SEQ       주조완료일 주여구분 지시GR종류 생산GR종류  생산GR공정     제강검사완료일         작업일  \
# 0        NaN  2023-06-26    1      A      A    8301  2023-06-27  2023-10-04
# 1        NaN  2023-06-26    1      A      A    8301  2023-06-27  2023-10-04
# 2        NaN  2023-01-02    1      A      A    8301  2023-01-04  2023-02-20
# 3        NaN  2023-01-02    1      A      A    8301  2023-01-04  2023-02-20
# 4        NaN  2023-01-02    1      A      A    8301  2023-01-04  2023-02-20
#
#   강관소재여부 주설비구분
# 0      N     C
# 1      N     C
# 2      N     W
# 3      N     W
# 4      N     W
#
# [5 rows x 59 columns]

# %%
# 대강종 파생변수 생성코드
INPUT_WT['대강종'] = INPUT_WT['강종그룹'].str[0]
# 대강종은 중강종 컬럼 앞에 배치
position = INPUT_WT.columns.get_loc('중강종')
INPUT_WT.insert(position, '대강종', INPUT_WT.pop('대강종'))
INPUT_WT.head()
# Out:
#        년월 HEAT_NO      LOT_NO  공정코드  구분 공장명 주조구분    재료코드 대강종 중강종  ...  \
# 0  202308  S54745  B360553701  9Y01  압연  산세    T  7730.0   S  SS  ...
# 1  202308  S54745  B360553901  9Y01  압연  산세    T  7730.0   S  SS  ...
# 2  202302  S52717  B310559703  9Y01  압연  산세    T  7730.0   S  SS  ...
# 3  202302  S52717  B310559702  9Y01  압연  산세    T  7730.0   S  SS  ...
# 4  202302  S52717  B310559701  9Y01  압연  산세    T  7730.0   S  SS  ...
#
#   STRAND_SEQ       주조완료일 주여구분 지시GR종류 생산GR종류 생산GR공정     제강검사완료일         작업일  \
# 0        NaN  2023-06-26    1      A      A   8301  2023-06-27  2023-10-04
# 1        NaN  2023-06-26    1      A      A   8301  2023-06-27  2023-10-04
# 2        NaN  2023-01-02    1      A      A   8301  2023-01-04  2023-02-20
# 3        NaN  2023-01-02    1      A      A   8301  2023-01-04  2023-02-20
# 4        NaN  2023-01-02    1      A      A   8301  2023-01-04  2023-02-20
#
#   강관소재여부 주설비구분
# 0      N     C
# 1      N     C
# 2      N     W
# 3      N     W
# 4      N     W
#
# [5 rows x 60 columns]

# %%
# Year Month Date' 열을 datetime 형식으로 변환
INPUT_WT['최종압연일자'] = pd.to_datetime(INPUT_WT['최종압연일자'])

#압연월 구분
INPUT_WT['압연월'] = INPUT_WT['최종압연일자'].dt.month
#INPUT_WT['압연월'] = INPUT_WT['압연월'].fillna("", inplace=True)  # Fill missing values with "" (or any other appropriate value)

# 압연월은 년월 컬럼 앞에 배치
position = INPUT_WT.columns.get_loc('년월')
INPUT_WT.insert(position, '압연월', INPUT_WT.pop('압연월'))
INPUT_WT.head()
# Out:
#    압연월      년월 HEAT_NO      LOT_NO  공정코드  구분 공장명 주조구분    재료코드 대강종  ...  \
# 0    8  202308  S54745  B360553701  9Y01  압연  산세    T  7730.0   S  ...
# 1    8  202308  S54745  B360553901  9Y01  압연  산세    T  7730.0   S  ...
# 2    2  202302  S52717  B310559703  9Y01  압연  산세    T  7730.0   S  ...
# 3    2  202302  S52717  B310559702  9Y01  압연  산세    T  7730.0   S  ...
# 4    2  202302  S52717  B310559701  9Y01  압연  산세    T  7730.0   S  ...
#
#   STRAND_SEQ       주조완료일 주여구분 지시GR종류 생산GR종류 생산GR공정     제강검사완료일         작업일  \
# 0        NaN  2023-06-26    1      A      A   8301  2023-06-27  2023-10-04
# 1        NaN  2023-06-26    1      A      A   8301  2023-06-27  2023-10-04
# 2        NaN  2023-01-02    1      A      A   8301  2023-01-04  2023-02-20
# 3        NaN  2023-01-02    1      A      A   8301  2023-01-04  2023-02-20
# 4        NaN  2023-01-02    1      A      A   8301  2023-01-04  2023-02-20
#
#   강관소재여부 주설비구분
# 0      N     C
# 1      N     C
# 2      N     W
# 3      N     W
# 4      N     W
#
# [5 rows x 61 columns]

# %%
#압연년 구분
INPUT_WT['압연년'] = INPUT_WT['최종압연일자'].dt.year
#INPUT_WT['압연년'] = INPUT_WT['압연년'].fillna("", inplace=True)  # Fill missing values with "" (or any other appropriate value)

# 압연년은 압연월 컬럼 앞에 배치
position = INPUT_WT.columns.get_loc('압연월')
INPUT_WT.insert(position, '압연년', INPUT_WT.pop('압연년'))
INPUT_WT.head()
# Out:
#     압연년  압연월      년월 HEAT_NO      LOT_NO  공정코드  구분 공장명 주조구분    재료코드  ...  \
# 0  2023    8  202308  S54745  B360553701  9Y01  압연  산세    T  7730.0  ...
# 1  2023    8  202308  S54745  B360553901  9Y01  압연  산세    T  7730.0  ...
# 2  2023    2  202302  S52717  B310559703  9Y01  압연  산세    T  7730.0  ...
# 3  2023    2  202302  S52717  B310559702  9Y01  압연  산세    T  7730.0  ...
# 4  2023    2  202302  S52717  B310559701  9Y01  압연  산세    T  7730.0  ...
#
#   STRAND_SEQ       주조완료일 주여구분 지시GR종류 생산GR종류 생산GR공정     제강검사완료일         작업일  \
# 0        NaN  2023-06-26    1      A      A   8301  2023-06-27  2023-10-04
# 1        NaN  2023-06-26    1      A      A   8301  2023-06-27  2023-10-04
# 2        NaN  2023-01-02    1      A      A   8301  2023-01-04  2023-02-20
# 3        NaN  2023-01-02    1      A      A   8301  2023-01-04  2023-02-20
# 4        NaN  2023-01-02    1      A      A   8301  2023-01-04  2023-02-20
#
#    강관소재여부 주설비구분
# 0       N     C
# 1       N     C
# 2       N     W
# 3       N     W
# 4       N     W
#
# [5 rows x 62 columns]

# %%
# 1,433처럼 중량에 콤마가 있는 Object는 콤마를 제거 후 숫자로 변환해야 함.
INPUT_WT['투입중량'] = INPUT_WT['투입중량'].str.replace(',', '').astype(int)
INPUT_WT['생산중량'] = INPUT_WT['생산중량'].str.replace(',', '').astype(int)
INPUT_WT.head()
# Out:
#     압연년  압연월      년월 HEAT_NO      LOT_NO  공정코드  구분 공장명 주조구분    재료코드  ...  \
# 0  2023    8  202308  S54745  B360553701  9Y01  압연  산세    T  7730.0  ...
# 1  2023    8  202308  S54745  B360553901  9Y01  압연  산세    T  7730.0  ...
# 2  2023    2  202302  S52717  B310559703  9Y01  압연  산세    T  7730.0  ...
# 3  2023    2  202302  S52717  B310559702  9Y01  압연  산세    T  7730.0  ...
# 4  2023    2  202302  S52717  B310559701  9Y01  압연  산세    T  7730.0  ...
#
#   STRAND_SEQ       주조완료일 주여구분 지시GR종류  생산GR종류  생산GR공정     제강검사완료일         작업일  \
# 0        NaN  2023-06-26    1      A       A    8301  2023-06-27  2023-10-04
# 1        NaN  2023-06-26    1      A       A    8301  2023-06-27  2023-10-04
# 2        NaN  2023-01-02    1      A       A    8301  2023-01-04  2023-02-20
# 3        NaN  2023-01-02    1      A       A    8301  2023-01-04  2023-02-20
# 4        NaN  2023-01-02    1      A       A    8301  2023-01-04  2023-02-20
#
#    강관소재여부 주설비구분
# 0       N     C
# 1       N     C
# 2       N     W
# 3       N     W
# 4       N     W
#
# [5 rows x 62 columns]

# %%
# 엑셀 파일로 저장
# pip install openpyxl 사전 설치 필요
output_path = 'pre_input_303F.xlsx'  # 저장할 파일 경로와 이름
INPUT_WT.to_excel(output_path, index=False)  # index=False로 설정하여 인덱스를 엑셀에 포함하지 않음
