# %%
import os
import re

def reorder_sentences_in_folder(input_folder_path):
    """
    Reorder sentences in all text files within a folder that appear disordered due to incorrect line breaks.
    Handle cases like abbreviations (e.g., "Washington, D.C.", "U.S.", "Mr.") where periods should not split sentences.
    Ensure that names and titles (e.g., "Mr. Yuki Kasumi") remain intact and are not split across lines.
    Ensure phrases like "Here in the U.S." and "Washington, D.C." are not broken into lines.
    Prevent line breaks for decimal numbers (e.g., "3.14").
    Avoid forcing sentence breaks and apply handling globally to prevent similar issues.
    Also removes unwanted tags like "</v>", "<v ->", and "-".
    Creates an output folder named "en_reorder" in the same directory as the input folder.
    Appends "_reorder" to the end of the original file name for the output.
    :param input_folder_path: Path to the folder containing input text files
    """
    try:
        # Define the output folder path
        output_folder_path = os.path.join(os.path.dirname(input_folder_path), "en_reorder")
        if not os.path.exists(output_folder_path):
            os.makedirs(output_folder_path)

        for filename in os.listdir(input_folder_path):
            if filename.endswith('.txt'):
                input_file_path = os.path.join(input_folder_path, filename)
                # Append "_reorder" to the output file name
                output_file_name = os.path.splitext(filename)[0] + "_reorder.txt"
                output_file_path = os.path.join(output_folder_path, output_file_name)

                with open(input_file_path, 'r', encoding='utf-8') as file:
                    lines = file.readlines()

                # Join lines to reconstruct the text, handling line breaks
                full_text = " ".join(line.strip() for line in lines)

                # Remove unwanted tags like </v>, <v ->, and "-"
                cleaned_text = re.sub(r"<.*?>", "", full_text)
                cleaned_text = re.sub(r"-", "", cleaned_text)

                # Protect abbreviations and special cases by temporarily replacing periods
                abbreviations = [
                    r"\bD\.C\b",
                    r"\bU\.S\b",
                    r"\bMr\.",
                    r"\bMrs\.",
                    r"\bDr\.",
                    r"\bJr\.",
                    r"\bSr\.",
                    r"\bMiss\.",
                    r"\bMs\.",
                ]
                for abbr in abbreviations:
                    cleaned_text = re.sub(abbr, lambda m: m.group(0).replace(".", "<<DOT>>"), cleaned_text)

                # Protect decimal numbers
                cleaned_text = re.sub(r"\b(\d+\.\d+)\b", lambda m: m.group(0).replace(".", "<<DOT>>"), cleaned_text)

                # Ensure titles, names, and phrases are preserved
                patterns_to_protect = [
                    r"Mr\. [A-Za-z]+ [A-Za-z]+",
                    r"Mrs\. [A-Za-z]+ [A-Za-z]+",
                    r"Ms\. [A-Za-z]+ [A-Za-z]+",
                    r"Dr\. [A-Za-z]+ [A-Za-z]+",
                    r"Here in the U\.S",
                    r"Washington, D\.C"
                ]
                for pattern in patterns_to_protect:
                    cleaned_text = re.sub(pattern, lambda m: m.group(0).replace(".", "<<DOT>>"), cleaned_text)

                # Avoid forcing sentence breaks, split only on strong punctuation boundaries
                sentences = []
                temp_sentence = ""
                for char in cleaned_text:
                    temp_sentence += char
                    if char in ['.', '?', '!'] and not temp_sentence.endswith("<<DOT>>"):
                        sentences.append(temp_sentence.strip())
                        temp_sentence = ""

                # Add any remaining text as the last sentence
                if temp_sentence.strip():
                    sentences.append(temp_sentence.strip())

                # Restore protected abbreviations, names, phrases, and decimal numbers
                reordered_text = "\n".join(sentences)
                reordered_text = reordered_text.replace("<<DOT>>", ".")

                # Save the reordered text to a new file
                with open(output_file_path, 'w', encoding='utf-8') as file:
                    file.write(reordered_text)

                print(f"Processed file: {filename} -> {output_file_name}")

    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
# Provide the path to your input folder
input_folder_path = r"C:/Temp/en"
reorder_sentences_in_folder(input_folder_path)
# Out:
# Processed file: videos_2025_january_2030-the-impact-of-xr-headsets-ar-and-smart-glasses-on-spatial-computing_en_text_only.txt -> videos_2025_january_2030-the-impact-of-xr-headsets-ar-and-smart-glasses-on-spatial-computing_en_text_only_reorder.txt
# Processed file: videos_2025_january_accenture-keynote_en_text_only.txt -> videos_2025_january_accenture-keynote_en_text_only_reorder.txt
# Processed file: videos_2025_january_advancing-women-s-health-innovations-challenges-and-solutions_en_text_only.txt -> videos_2025_january_advancing-women-s-health-innovations-challenges-and-solutions_en_text_only_reorder.txt
# Processed file: videos_2025_january_Automotive-Cybersecurity-Revs-Up_en_text_only.txt -> videos_2025_january_Automotive-Cybersecurity-Revs-Up_en_text_only_reorder.txt
# Processed file: videos_2025_january_Autonomous-Vehicles-The-Future-is-Finally-Here_en_text_only.txt -> videos_2025_january_Autonomous-Vehicles-The-Future-is-Finally-Here_en_text_only_reorder.txt
# Processed file: videos_2025_january_Beyond-the-Bottom-Line-Driving-Quality-and-Value-in-Healthcare_en_text_only.txt -> videos_2025_january_Beyond-the-Bottom-Line-Driving-Quality-and-Value-in-Healthcare_en_text_only_reorder.txt
# Processed file: videos_2025_january_c-space-keynote-siriusxm_en_text_only.txt -> videos_2025_january_c-space-keynote-siriusxm_en_text_only_reorder.txt
# Processed file: videos_2025_january_calling-from-space_en_text_only.txt -> videos_2025_january_calling-from-space_en_text_only_reorder.txt
# Processed file: videos_2025_january_cloud-data-centers-for-corporate-satellite-connectivity_en_text_only.txt -> videos_2025_january_cloud-data-centers-for-corporate-satellite-connectivity_en_text_only_reorder.txt
# Processed file: videos_2025_january_connected-vehicle-safety-reducing-roadway-risk-saving-lives_en_text_only.txt -> videos_2025_january_connected-vehicle-safety-reducing-roadway-risk-saving-lives_en_text_only_reorder.txt
# Processed file: videos_2025_january_constellations-and-debris-maintaining-sustainable-space-practices_en_text_only.txt -> videos_2025_january_constellations-and-debris-maintaining-sustainable-space-practices_en_text_only_reorder.txt
# Processed file: videos_2025_january_creating-the-ultimate-vehicle-experience_en_text_only.txt -> videos_2025_january_creating-the-ultimate-vehicle-experience_en_text_only_reorder.txt
# Processed file: videos_2025_january_cta-state-of-the-industry-address-and-panasonic-holdings-keynote_en_text_only.txt -> videos_2025_january_cta-state-of-the-industry-address-and-panasonic-holdings-keynote_en_text_only_reorder.txt
# Processed file: videos_2025_january_delta-keynote-experience_en_text_only.txt -> videos_2025_january_delta-keynote-experience_en_text_only_reorder.txt
# Processed file: videos_2025_january_digital-therapeutics-the-new-frontier_en_text_only.txt -> videos_2025_january_digital-therapeutics-the-new-frontier_en_text_only_reorder.txt
# Processed file: videos_2025_january_driving-into-the-future-the-impact-of-connected-cars_en_text_only.txt -> videos_2025_january_driving-into-the-future-the-impact-of-connected-cars_en_text_only_reorder.txt
# Processed file: videos_2025_january_dual-use-autonomy-and-drones-a-path-to-commercialization_en_text_only.txt -> videos_2025_january_dual-use-autonomy-and-drones-a-path-to-commercialization_en_text_only_reorder.txt
# Processed file: videos_2025_january_embracing-ai-revolutionizing-the-future-of-work_en_text_only.txt -> videos_2025_january_embracing-ai-revolutionizing-the-future-of-work_en_text_only_reorder.txt
# Processed file: videos_2025_january_fighting-deepfakes-disinformation-and-misinformation_en_text_only.txt -> videos_2025_january_fighting-deepfakes-disinformation-and-misinformation_en_text_only_reorder.txt
# Processed file: videos_2025_january_future-health-workforce_en_text_only.txt -> videos_2025_january_future-health-workforce_en_text_only_reorder.txt
# Processed file: videos_2025_january_global-ai-investment-trends_en_text_only.txt -> videos_2025_january_global-ai-investment-trends_en_text_only_reorder.txt
# Processed file: videos_2025_january_global-industry-challenge-celebrating-international-year-of-quantum_en_text_only.txt -> videos_2025_january_global-industry-challenge-celebrating-international-year-of-quantum_en_text_only_reorder.txt
# Processed file: videos_2025_january_Health-AI-in-2030_en_text_only.txt -> videos_2025_january_Health-AI-in-2030_en_text_only_reorder.txt
# Processed file: videos_2025_january_health-at-home-where-health-meets-smart-living_en_text_only.txt -> videos_2025_january_health-at-home-where-health-meets-smart-living_en_text_only_reorder.txt
# Processed file: videos_2025_january_how-businesses-are-using-spatial-computing-to-drive-measurable-results_en_text_only.txt -> videos_2025_january_how-businesses-are-using-spatial-computing-to-drive-measurable-results_en_text_only_reorder.txt
# Processed file: videos_2025_january_how-has-ai-impacted-auto-in-every-possible-way_en_text_only.txt -> videos_2025_january_how-has-ai-impacted-auto-in-every-possible-way_en_text_only_reorder.txt
# Processed file: videos_2025_january_in-a-relationship-humans-robots-smart-manufacturing-supply-chain_en_text_only.txt -> videos_2025_january_in-a-relationship-humans-robots-smart-manufacturing-supply-chain_en_text_only_reorder.txt
# Processed file: videos_2025_january_King-of-Your-Hill-Your-Home-is-the-Nexus-for-a-Sustainable-Future_en_text_only.txt -> videos_2025_january_King-of-Your-Hill-Your-Home-is-the-Nexus-for-a-Sustainable-Future_en_text_only_reorder.txt
# Processed file: videos_2025_january_leading-the-way-for-a-carbon-neutral-future_en_text_only.txt -> videos_2025_january_leading-the-way-for-a-carbon-neutral-future_en_text_only_reorder.txt
# Processed file: videos_2025_january_mobility-innovations-unleashing-new-possibilities_en_text_only.txt -> videos_2025_january_mobility-innovations-unleashing-new-possibilities_en_text_only_reorder.txt
# Processed file: videos_2025_january_mobility-intel-report_en_text_only.txt -> videos_2025_january_mobility-intel-report_en_text_only_reorder.txt
# Processed file: videos_2025_january_Next-Gen-Wearable-Tech-Shaping-the-Future_en_text_only.txt -> videos_2025_january_Next-Gen-Wearable-Tech-Shaping-the-Future_en_text_only_reorder.txt
# Processed file: videos_2025_january_next-level-innovation_en_text_only.txt -> videos_2025_january_next-level-innovation_en_text_only_reorder.txt
# Processed file: videos_2025_january_nvidia-keynote_en_text_only.txt -> videos_2025_january_nvidia-keynote_en_text_only_reorder.txt
# Processed file: videos_2025_january_predictive-ai-transforming-customer-service-and-business_en_text_only.txt -> videos_2025_january_predictive-ai-transforming-customer-service-and-business_en_text_only_reorder.txt
# Processed file: videos_2025_january_quantum-is-here-computing-advancements-and-tangible-applications_en_text_only.txt -> videos_2025_january_quantum-is-here-computing-advancements-and-tangible-applications_en_text_only_reorder.txt
# Processed file: videos_2025_january_quantum-is-now-unprecedented-improvement-in-precision-and-sensitivity_en_text_only.txt -> videos_2025_january_quantum-is-now-unprecedented-improvement-in-precision-and-sensitivity_en_text_only_reorder.txt
# Processed file: videos_2025_january_rechargeable-batteries-in-consumer-tech-a-path-to-sustainability_en_text_only.txt -> videos_2025_january_rechargeable-batteries-in-consumer-tech-a-path-to-sustainability_en_text_only_reorder.txt
# Processed file: videos_2025_january_robots-at-retail_en_text_only.txt -> videos_2025_january_robots-at-retail_en_text_only_reorder.txt
# Processed file: videos_2025_january_spatial-computing-a-state-of-the-union_en_text_only.txt -> videos_2025_january_spatial-computing-a-state-of-the-union_en_text_only_reorder.txt
# Processed file: videos_2025_january_Spotlight-Panel-The-Future-of-Health-Views-from-the-Top_en_text_only.txt -> videos_2025_january_Spotlight-Panel-The-Future-of-Health-Views-from-the-Top_en_text_only_reorder.txt
# Processed file: videos_2025_january_sustainability-and-the-new-product-service-economy_en_text_only.txt -> videos_2025_january_sustainability-and-the-new-product-service-economy_en_text_only_reorder.txt
# Processed file: videos_2025_january_sustainable-semiconductors-standards-for-a-greener-tech-future_en_text_only.txt -> videos_2025_january_sustainable-semiconductors-standards-for-a-greener-tech-future_en_text_only_reorder.txt
# Processed file: videos_2025_january_Tech-in-Regenerative-Medicine_en_text_only.txt -> videos_2025_january_Tech-in-Regenerative-Medicine_en_text_only_reorder.txt
# Processed file: videos_2025_january_tech-on-the-frontlines-adapting-tech-for-healthcare_en_text_only.txt -> videos_2025_january_tech-on-the-frontlines-adapting-tech-for-healthcare_en_text_only_reorder.txt
# Processed file: videos_2025_january_the-future-of-entertainment-media_en_text_only.txt -> videos_2025_january_the-future-of-entertainment-media_en_text_only_reorder.txt
# Processed file: videos_2025_january_the-future-of-funding-investment-trends-shaping-tomorrows-care_en_text_only.txt -> videos_2025_january_the-future-of-funding-investment-trends-shaping-tomorrows-care_en_text_only_reorder.txt
# Processed file: videos_2025_january_the-green-dream-how-sustainable-vc-went-from-ethos-to-opportunity_en_text_only.txt -> videos_2025_january_the-green-dream-how-sustainable-vc-went-from-ethos-to-opportunity_en_text_only_reorder.txt
# Processed file: videos_2025_january_the-race-for-generative-ai-and-llm-supremacy_en_text_only.txt -> videos_2025_january_the-race-for-generative-ai-and-llm-supremacy_en_text_only_reorder.txt
# Processed file: videos_2025_january_the-rise-of-personalized-medicine-genomics-and-beyond_en_text_only.txt -> videos_2025_january_the-rise-of-personalized-medicine-genomics-and-beyond_en_text_only_reorder.txt
# Processed file: videos_2025_january_The-Road-Ahead-Software-Defined-Vehicles_en_text_only.txt -> videos_2025_january_The-Road-Ahead-Software-Defined-Vehicles_en_text_only_reorder.txt
# Processed file: videos_2025_january_Transforming-Commercial-Mobility-AI-Driven-Autonomous-Solutions_en_text_only.txt -> videos_2025_january_Transforming-Commercial-Mobility-AI-Driven-Autonomous-Solutions_en_text_only_reorder.txt
# Processed file: videos_2025_january_Trends-in-Electric-Car-Consumption-Who-What-Where_en_text_only.txt -> videos_2025_january_Trends-in-Electric-Car-Consumption-Who-What-Where_en_text_only_reorder.txt
# Processed file: videos_2025_january_vehicle-payments-the-road-ahead_en_text_only.txt -> videos_2025_january_vehicle-payments-the-road-ahead_en_text_only_reorder.txt
# Processed file: videos_2025_january_volvo-group-keynote_en_text_only.txt -> videos_2025_january_volvo-group-keynote_en_text_only_reorder.txt
# Processed file: videos_2025_january_what-s-next-in-vehicle-tech_en_text_only.txt -> videos_2025_january_what-s-next-in-vehicle-tech_en_text_only_reorder.txt
# Processed file: videos_2025_january_workforce-readiness-and-the-global-economy_en_text_only.txt -> videos_2025_january_workforce-readiness-and-the-global-economy_en_text_only_reorder.txt
# Processed file: videos_2025_january_x-corp-keynote_en_text_only.txt -> videos_2025_january_x-corp-keynote_en_text_only_reorder.txt
