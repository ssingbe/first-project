# %%
# Importing libraries
import pandas as pd

# %%
# 투입량 Loading
INPUT_WT = pd.read_csv('S300_flaw_input_hangul.csv', encoding='cp949')
INPUT_WT.head()
# Out:
# C:\Users\seah\AppData\Local\Temp\ipykernel_5500\2951550557.py:2: DtypeWarning: Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#   INPUT_WT = pd.read_csv('S300_flaw_input_hangul.csv', encoding='cp949')
#        년월 HEAT_NO      LOT_NO  공정코드  구분 공장명 주조구분  재료코드 강종그룹    강종코드  ...  \
# 0  202206  S49412  B230816400  9Y01  압연  산세    T  6830  SSH  SSH030  ...
# 1  202205  S49483  B230772807  9Y01  압연  산세    T  6830  SSJ  SSJ025  ...
# 2  202205  S49483  B230772804  9Y01  압연  산세    T  6830  SSJ  SSJ025  ...
# 3  202206  S50180  B250801100  9Y01  압연  산세    T  6830  SSM  SSM104  ...
# 4  202206  S50113  B240827304  9Y01  압연  산세    T  6830  SSA  SSA162  ...
#
#   STRAND_SEQ       주조완료일 주여구분 지시GR종류 생산GR종류 생산GR공정     제강검사완료일         작업일  \
# 0        5.0  2022-03-04    1      A      A   8301  2022-03-07  2022-07-01
# 1       10.0  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01
# 2        4.0  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01
# 3        8.0  2022-05-03    1      A      A   8301  2022-05-04  2022-07-01
# 4        7.0  2022-04-28    1      C      C   8301  2022-05-02  2022-07-01
#
#   강관소재여부 주설비구분
# 0      N     C
# 1      N     C
# 2      N     C
# 3      N     C
# 4      N     C
#
# [5 rows x 58 columns]

# %%
# 중강종 파생변수 생성코드
INPUT_WT['중강종'] = INPUT_WT['강종그룹'].str[0:2]
# STEEL_GROUP_L는 Steel Grade 컬럼 앞에 배치
position = INPUT_WT.columns.get_loc('강종그룹')
INPUT_WT.insert(position, '중강종', INPUT_WT.pop('중강종'))
INPUT_WT.head()
#print(INPUT_WT['중강종'])
# Out:
#        년월 HEAT_NO      LOT_NO  공정코드  구분 공장명 주조구분  재료코드 중강종 강종그룹  ...  \
# 0  202206  S49412  B230816400  9Y01  압연  산세    T  6830  SS  SSH  ...
# 1  202205  S49483  B230772807  9Y01  압연  산세    T  6830  SS  SSJ  ...
# 2  202205  S49483  B230772804  9Y01  압연  산세    T  6830  SS  SSJ  ...
# 3  202206  S50180  B250801100  9Y01  압연  산세    T  6830  SS  SSM  ...
# 4  202206  S50113  B240827304  9Y01  압연  산세    T  6830  SS  SSA  ...
#
#   STRAND_SEQ       주조완료일 주여구분 지시GR종류 생산GR종류 생산GR공정     제강검사완료일         작업일  \
# 0        5.0  2022-03-04    1      A      A   8301  2022-03-07  2022-07-01
# 1       10.0  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01
# 2        4.0  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01
# 3        8.0  2022-05-03    1      A      A   8301  2022-05-04  2022-07-01
# 4        7.0  2022-04-28    1      C      C   8301  2022-05-02  2022-07-01
#
#   강관소재여부 주설비구분
# 0      N     C
# 1      N     C
# 2      N     C
# 3      N     C
# 4      N     C
#
# [5 rows x 59 columns]

# %%
# 대강종 파생변수 생성코드
INPUT_WT['대강종'] = INPUT_WT['강종그룹'].str[0]
# 대강종은 중강종 컬럼 앞에 배치
position = INPUT_WT.columns.get_loc('중강종')
INPUT_WT.insert(position, '대강종', INPUT_WT.pop('대강종'))
INPUT_WT.head()
# Out:
#        년월 HEAT_NO      LOT_NO  공정코드  구분 공장명 주조구분  재료코드 대강종 중강종  ...  \
# 0  202206  S49412  B230816400  9Y01  압연  산세    T  6830   S  SS  ...
# 1  202205  S49483  B230772807  9Y01  압연  산세    T  6830   S  SS  ...
# 2  202205  S49483  B230772804  9Y01  압연  산세    T  6830   S  SS  ...
# 3  202206  S50180  B250801100  9Y01  압연  산세    T  6830   S  SS  ...
# 4  202206  S50113  B240827304  9Y01  압연  산세    T  6830   S  SS  ...
#
#   STRAND_SEQ       주조완료일 주여구분 지시GR종류 생산GR종류 생산GR공정     제강검사완료일         작업일  \
# 0        5.0  2022-03-04    1      A      A   8301  2022-03-07  2022-07-01
# 1       10.0  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01
# 2        4.0  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01
# 3        8.0  2022-05-03    1      A      A   8301  2022-05-04  2022-07-01
# 4        7.0  2022-04-28    1      C      C   8301  2022-05-02  2022-07-01
#
#   강관소재여부 주설비구분
# 0      N     C
# 1      N     C
# 2      N     C
# 3      N     C
# 4      N     C
#
# [5 rows x 60 columns]

# %%
#외경구분
INPUT_WT['외경구분'] = INPUT_WT['외경'].apply(lambda x: 'Ø15~25' if x <= 25.5 else 'Ø26~36')
position = INPUT_WT.columns.get_loc('외경')
INPUT_WT.insert(position, '외경구분', INPUT_WT.pop('외경구분'))
INPUT_WT.head()
#print(INPUT_WT)
# Out:
#        년월 HEAT_NO      LOT_NO  공정코드  구분 공장명 주조구분  재료코드 대강종 중강종  ...  \
# 0  202206  S49412  B230816400  9Y01  압연  산세    T  6830   S  SS  ...
# 1  202205  S49483  B230772807  9Y01  압연  산세    T  6830   S  SS  ...
# 2  202205  S49483  B230772804  9Y01  압연  산세    T  6830   S  SS  ...
# 3  202206  S50180  B250801100  9Y01  압연  산세    T  6830   S  SS  ...
# 4  202206  S50113  B240827304  9Y01  압연  산세    T  6830   S  SS  ...
#
#   STRAND_SEQ       주조완료일 주여구분 지시GR종류 생산GR종류 생산GR공정     제강검사완료일         작업일  \
# 0        5.0  2022-03-04    1      A      A   8301  2022-03-07  2022-07-01
# 1       10.0  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01
# 2        4.0  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01
# 3        8.0  2022-05-03    1      A      A   8301  2022-05-04  2022-07-01
# 4        7.0  2022-04-28    1      C      C   8301  2022-05-02  2022-07-01
#
#   강관소재여부 주설비구분
# 0      N     C
# 1      N     C
# 2      N     C
# 3      N     C
# 4      N     C
#
# [5 rows x 61 columns]

# %%
# Year Month Date' 열을 datetime 형식으로 변환
INPUT_WT['최종압연일자'] = pd.to_datetime(INPUT_WT['최종압연일자'])

#압연월 구분
INPUT_WT['압연월'] = INPUT_WT['최종압연일자'].dt.month

# 압연월은 년월 컬럼 앞에 배치
position = INPUT_WT.columns.get_loc('년월')
INPUT_WT.insert(position, '압연월', INPUT_WT.pop('압연월'))
INPUT_WT.head()
# Out:
#    압연월      년월 HEAT_NO      LOT_NO  공정코드  구분 공장명 주조구분  재료코드 대강종  ...  \
# 0    6  202206  S49412  B230816400  9Y01  압연  산세    T  6830   S  ...
# 1    5  202205  S49483  B230772807  9Y01  압연  산세    T  6830   S  ...
# 2    5  202205  S49483  B230772804  9Y01  압연  산세    T  6830   S  ...
# 3    6  202206  S50180  B250801100  9Y01  압연  산세    T  6830   S  ...
# 4    6  202206  S50113  B240827304  9Y01  압연  산세    T  6830   S  ...
#
#   STRAND_SEQ       주조완료일 주여구분 지시GR종류 생산GR종류 생산GR공정     제강검사완료일         작업일  \
# 0        5.0  2022-03-04    1      A      A   8301  2022-03-07  2022-07-01
# 1       10.0  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01
# 2        4.0  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01
# 3        8.0  2022-05-03    1      A      A   8301  2022-05-04  2022-07-01
# 4        7.0  2022-04-28    1      C      C   8301  2022-05-02  2022-07-01
#
#   강관소재여부 주설비구분
# 0      N     C
# 1      N     C
# 2      N     C
# 3      N     C
# 4      N     C
#
# [5 rows x 62 columns]

# %%
#압연년 구분
INPUT_WT['압연년'] = INPUT_WT['최종압연일자'].dt.year

# 압연년은 압연월 컬럼 앞에 배치
position = INPUT_WT.columns.get_loc('압연월')
INPUT_WT.insert(position, '압연년', INPUT_WT.pop('압연년'))
INPUT_WT.head()
# Out:
#     압연년  압연월      년월 HEAT_NO      LOT_NO  공정코드  구분 공장명 주조구분  재료코드  ...  \
# 0  2022    6  202206  S49412  B230816400  9Y01  압연  산세    T  6830  ...
# 1  2022    5  202205  S49483  B230772807  9Y01  압연  산세    T  6830  ...
# 2  2022    5  202205  S49483  B230772804  9Y01  압연  산세    T  6830  ...
# 3  2022    6  202206  S50180  B250801100  9Y01  압연  산세    T  6830  ...
# 4  2022    6  202206  S50113  B240827304  9Y01  압연  산세    T  6830  ...
#
#   STRAND_SEQ       주조완료일 주여구분 지시GR종류 생산GR종류 생산GR공정     제강검사완료일         작업일  \
# 0        5.0  2022-03-04    1      A      A   8301  2022-03-07  2022-07-01
# 1       10.0  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01
# 2        4.0  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01
# 3        8.0  2022-05-03    1      A      A   8301  2022-05-04  2022-07-01
# 4        7.0  2022-04-28    1      C      C   8301  2022-05-02  2022-07-01
#
#   강관소재여부 주설비구분
# 0      N     C
# 1      N     C
# 2      N     C
# 3      N     C
# 4      N     C
#
# [5 rows x 63 columns]

# %%
#압연 년월을 압연 Roll 단위 구분
INPUT_WT['압연일'] = INPUT_WT['최종압연일자'].dt.day
character = "-"

def Roll_Mth(row):
    if row['압연일'] >10:
        return row['압연월']
    else :
        return row['압연월'] - 1
INPUT_WT['Roll_Mth'] = INPUT_WT.apply(Roll_Mth, axis=1)

# Roll_Mth은 R_Year 컬럼 앞에 배치
position = INPUT_WT.columns.get_loc('압연년')
INPUT_WT.insert(position, 'Roll_Mth', INPUT_WT.pop('Roll_Mth'))

INPUT_WT['Roll_Yr_Mth'] = INPUT_WT['압연년'].astype(str) + character + INPUT_WT['Roll_Mth'].astype(str)
# Roll_Yr_Mth은 Roll_Mth 컬럼 앞에 배치
position = INPUT_WT.columns.get_loc('Roll_Mth')
INPUT_WT.insert(position, 'Roll_Yr_Mth', INPUT_WT.pop('Roll_Yr_Mth'))

INPUT_WT.head()
#print(INPUT_WT['Roll_Yr_Mth'])
# Out:
#   Roll_Yr_Mth  Roll_Mth   압연년  압연월      년월 HEAT_NO      LOT_NO  공정코드  구분 공장명  \
# 0      2022-6         6  2022    6  202206  S49412  B230816400  9Y01  압연  산세
# 1      2022-5         5  2022    5  202205  S49483  B230772807  9Y01  압연  산세
# 2      2022-5         5  2022    5  202205  S49483  B230772804  9Y01  압연  산세
# 3      2022-6         6  2022    6  202206  S50180  B250801100  9Y01  압연  산세
# 4      2022-6         6  2022    6  202206  S50113  B240827304  9Y01  압연  산세
#
#    ...       주조완료일 주여구분 지시GR종류 생산GR종류 생산GR공정     제강검사완료일         작업일 강관소재여부  \
# 0  ...  2022-03-04    1      A      A   8301  2022-03-07  2022-07-01      N
# 1  ...  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01      N
# 2  ...  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01      N
# 3  ...  2022-05-03    1      A      A   8301  2022-05-04  2022-07-01      N
# 4  ...  2022-04-28    1      C      C   8301  2022-05-02  2022-07-01      N
#
#   주설비구분 압연일
# 0     C  19
# 1     C  20
# 2     C  20
# 3     C  20
# 4     C  22
#
# [5 rows x 66 columns]

# %%
#분기 구분 코드
INPUT_WT['Roll_분기'] = INPUT_WT['Roll_Mth'].apply(lambda month: '1Q' if month <= 3 else '2Q' if month <= 6 else '3Q' if month<= 9 else '4Q')

# R_Quarter은 Roll_Yr_Mth 컬럼 앞에 배치
position = INPUT_WT.columns.get_loc('Roll_Yr_Mth')
INPUT_WT.insert(position, 'Roll_분기', INPUT_WT.pop('Roll_분기'))

INPUT_WT.head()
#print(INPUT_WT['R_Quarter'])
# Out:
#   Roll_분기 Roll_Yr_Mth  Roll_Mth   압연년  압연월      년월 HEAT_NO      LOT_NO  공정코드  \
# 0      2Q      2022-6         6  2022    6  202206  S49412  B230816400  9Y01
# 1      2Q      2022-5         5  2022    5  202205  S49483  B230772807  9Y01
# 2      2Q      2022-5         5  2022    5  202205  S49483  B230772804  9Y01
# 3      2Q      2022-6         6  2022    6  202206  S50180  B250801100  9Y01
# 4      2Q      2022-6         6  2022    6  202206  S50113  B240827304  9Y01
#
#    구분  ...       주조완료일 주여구분 지시GR종류 생산GR종류 생산GR공정     제강검사완료일         작업일  \
# 0  압연  ...  2022-03-04    1      A      A   8301  2022-03-07  2022-07-01
# 1  압연  ...  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01
# 2  압연  ...  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01
# 3  압연  ...  2022-05-03    1      A      A   8301  2022-05-04  2022-07-01
# 4  압연  ...  2022-04-28    1      C      C   8301  2022-05-02  2022-07-01
#
#   강관소재여부 주설비구분 압연일
# 0      N     C  19
# 1      N     C  20
# 2      N     C  20
# 3      N     C  20
# 4      N     C  22
#
# [5 rows x 67 columns]

# %%
# 1,433처럼 중량에 콤마가 있는 Object는 콤마를 제거 후 숫자로 변환해야 함.
INPUT_WT['투입중량'] = INPUT_WT['투입중량'].str.replace(',', '').astype(int)
INPUT_WT['생산중량'] = INPUT_WT['생산중량'].str.replace(',', '').astype(int)
INPUT_WT.head()
# Out:
#   Roll_분기 Roll_Yr_Mth  Roll_Mth   압연년  압연월      년월 HEAT_NO      LOT_NO  공정코드  \
# 0      2Q      2022-6         6  2022    6  202206  S49412  B230816400  9Y01
# 1      2Q      2022-5         5  2022    5  202205  S49483  B230772807  9Y01
# 2      2Q      2022-5         5  2022    5  202205  S49483  B230772804  9Y01
# 3      2Q      2022-6         6  2022    6  202206  S50180  B250801100  9Y01
# 4      2Q      2022-6         6  2022    6  202206  S50113  B240827304  9Y01
#
#    구분  ...       주조완료일 주여구분 지시GR종류 생산GR종류 생산GR공정     제강검사완료일         작업일  \
# 0  압연  ...  2022-03-04    1      A      A   8301  2022-03-07  2022-07-01
# 1  압연  ...  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01
# 2  압연  ...  2022-03-09    1      A      A   B301  2022-03-10  2022-07-01
# 3  압연  ...  2022-05-03    1      A      A   8301  2022-05-04  2022-07-01
# 4  압연  ...  2022-04-28    1      C      C   8301  2022-05-02  2022-07-01
#
#    강관소재여부  주설비구분 압연일
# 0       N      C  19
# 1       N      C  20
# 2       N      C  20
# 3       N      C  20
# 4       N      C  22
#
# [5 rows x 67 columns]

# %%
# 엑셀 파일로 저장
# pip install openpyxl 사전 설치 필요
output_path = 'preprocessed_input_data.xlsx'  # 저장할 파일 경로와 이름
INPUT_WT.to_excel(output_path, index=False)  # index=False로 설정하여 인덱스를 엑셀에 포함하지 않음
