# %%
# Importing libraries
import pandas as pd

# %%
# 불량량 Loading
Defect_WT = pd.read_csv('defect_316LDSB.csv', encoding='cp949')
Defect_WT.head()
# Out:
#           년월일  업무구분  공장구분 HEAT_NO      LOT_NO         PON  공정순위 주조구분  재료코드  \
# 0  2023-09-22     2     9  S54805  B360593201  D23W9W1414    80    T  7730
# 1  2023-09-22     2     9  S54805  B360593201  D23W9W1414    80    T  7730
# 2  2023-07-24     2     9  S54204  B350698202  D23W7W1114    90    T  7730
# 3  2024-04-29     2     9  S57283  B440412302  D24W3W1469    80    T  7730
# 4  2024-04-29     2     9  S57283  B440412201  D24W4W1343    80    T  7730
#
#   강종그룹  ... 압연일자4 압연외경4 압연폭4 최종압연공정      최종압연일자 제품압연작업조        생성일시 HCR 투입중량  \
# 0  SSM  ...   NaN     0    0   8100  2023-09-21       B  2023-10-05 NaN  NaN
# 1  SSM  ...   NaN     0    0   8100  2023-09-21       B  2023-10-05 NaN  NaN
# 2  SSM  ...   NaN     0    0   8100  2023-07-23       B  2023-08-07 NaN  NaN
# 3  SSM  ...   NaN     0    0   8100  2024-04-28       C  2024-05-03 NaN  NaN
# 4  SSM  ...   NaN     0    0   8100  2024-04-28       C  2024-05-03 NaN  NaN
#
#   주설비구분
# 0     C
# 1     C
# 2     C
# 3     C
# 4     C
#
# [5 rows x 82 columns]

# %%
# 중강종 파생변수 생성코드
Defect_WT['중강종'] = Defect_WT['강종그룹'].str[0:2]
# STEEL_GROUP_L는 Steel Grade 컬럼 앞에 배치
position = Defect_WT.columns.get_loc('강종그룹')
Defect_WT.insert(position, '중강종', Defect_WT.pop('중강종'))
Defect_WT.head()
#print(Defect_WT['중강종'])
# Out:
#           년월일  업무구분  공장구분 HEAT_NO      LOT_NO         PON  공정순위 주조구분  재료코드  \
# 0  2023-09-22     2     9  S54805  B360593201  D23W9W1414    80    T  7730
# 1  2023-09-22     2     9  S54805  B360593201  D23W9W1414    80    T  7730
# 2  2023-07-24     2     9  S54204  B350698202  D23W7W1114    90    T  7730
# 3  2024-04-29     2     9  S57283  B440412302  D24W3W1469    80    T  7730
# 4  2024-04-29     2     9  S57283  B440412201  D24W4W1343    80    T  7730
#
#   중강종  ... 압연일자4 압연외경4 압연폭4 최종압연공정      최종압연일자 제품압연작업조        생성일시 HCR 투입중량  \
# 0  SS  ...   NaN     0    0   8100  2023-09-21       B  2023-10-05 NaN  NaN
# 1  SS  ...   NaN     0    0   8100  2023-09-21       B  2023-10-05 NaN  NaN
# 2  SS  ...   NaN     0    0   8100  2023-07-23       B  2023-08-07 NaN  NaN
# 3  SS  ...   NaN     0    0   8100  2024-04-28       C  2024-05-03 NaN  NaN
# 4  SS  ...   NaN     0    0   8100  2024-04-28       C  2024-05-03 NaN  NaN
#
#   주설비구분
# 0     C
# 1     C
# 2     C
# 3     C
# 4     C
#
# [5 rows x 83 columns]

# %%
# 대강종 파생변수 생성코드
Defect_WT['대강종'] = Defect_WT['강종그룹'].str[0]
# 대강종은 중강종 컬럼 앞에 배치
position = Defect_WT.columns.get_loc('중강종')
Defect_WT.insert(position, '대강종', Defect_WT.pop('대강종'))
Defect_WT.head()
# Out:
#           년월일  업무구분  공장구분 HEAT_NO      LOT_NO         PON  공정순위 주조구분  재료코드  \
# 0  2023-09-22     2     9  S54805  B360593201  D23W9W1414    80    T  7730
# 1  2023-09-22     2     9  S54805  B360593201  D23W9W1414    80    T  7730
# 2  2023-07-24     2     9  S54204  B350698202  D23W7W1114    90    T  7730
# 3  2024-04-29     2     9  S57283  B440412302  D24W3W1469    80    T  7730
# 4  2024-04-29     2     9  S57283  B440412201  D24W4W1343    80    T  7730
#
#   대강종  ... 압연일자4 압연외경4 압연폭4 최종압연공정      최종압연일자 제품압연작업조        생성일시 HCR 투입중량  \
# 0   S  ...   NaN     0    0   8100  2023-09-21       B  2023-10-05 NaN  NaN
# 1   S  ...   NaN     0    0   8100  2023-09-21       B  2023-10-05 NaN  NaN
# 2   S  ...   NaN     0    0   8100  2023-07-23       B  2023-08-07 NaN  NaN
# 3   S  ...   NaN     0    0   8100  2024-04-28       C  2024-05-03 NaN  NaN
# 4   S  ...   NaN     0    0   8100  2024-04-28       C  2024-05-03 NaN  NaN
#
#   주설비구분
# 0     C
# 1     C
# 2     C
# 3     C
# 4     C
#
# [5 rows x 84 columns]

# %%
# Year Month Date' 열을 datetime 형식으로 변환
Defect_WT['최종압연일자'] = pd.to_datetime(Defect_WT['최종압연일자'])

#압연월 구분
Defect_WT['압연월'] = Defect_WT['최종압연일자'].dt.month
#Defect_WT['압연월'] = Defect_WT['압연월'].fillna("", inplace=True)  # Fill missing values with "" (or any other appropriate value)

# 압연월은 년월 컬럼 앞에 배치
position = Defect_WT.columns.get_loc('년월일')
Defect_WT.insert(position, '압연월', Defect_WT.pop('압연월'))
Defect_WT.head()
# Out:
#    압연월         년월일  업무구분  공장구분 HEAT_NO      LOT_NO         PON  공정순위 주조구분  \
# 0    9  2023-09-22     2     9  S54805  B360593201  D23W9W1414    80    T
# 1    9  2023-09-22     2     9  S54805  B360593201  D23W9W1414    80    T
# 2    7  2023-07-24     2     9  S54204  B350698202  D23W7W1114    90    T
# 3    4  2024-04-29     2     9  S57283  B440412302  D24W3W1469    80    T
# 4    4  2024-04-29     2     9  S57283  B440412201  D24W4W1343    80    T
#
#    재료코드  ... 압연일자4 압연외경4 압연폭4 최종압연공정     최종압연일자 제품압연작업조        생성일시 HCR 투입중량  \
# 0  7730  ...   NaN     0    0   8100 2023-09-21       B  2023-10-05 NaN  NaN
# 1  7730  ...   NaN     0    0   8100 2023-09-21       B  2023-10-05 NaN  NaN
# 2  7730  ...   NaN     0    0   8100 2023-07-23       B  2023-08-07 NaN  NaN
# 3  7730  ...   NaN     0    0   8100 2024-04-28       C  2024-05-03 NaN  NaN
# 4  7730  ...   NaN     0    0   8100 2024-04-28       C  2024-05-03 NaN  NaN
#
#   주설비구분
# 0     C
# 1     C
# 2     C
# 3     C
# 4     C
#
# [5 rows x 85 columns]

# %%
#압연년 구분
Defect_WT['압연년'] = Defect_WT['최종압연일자'].dt.year
#Defect_WT['압연년'] = Defect_WT['압연년'].fillna("", inplace=True)  # Fill missing values with "" (or any other appropriate value)

# 압연년은 압연월 컬럼 앞에 배치
position = Defect_WT.columns.get_loc('압연월')
Defect_WT.insert(position, '압연년', Defect_WT.pop('압연년'))
Defect_WT.head()
# Out:
#     압연년  압연월         년월일  업무구분  공장구분 HEAT_NO      LOT_NO         PON  공정순위  \
# 0  2023    9  2023-09-22     2     9  S54805  B360593201  D23W9W1414    80
# 1  2023    9  2023-09-22     2     9  S54805  B360593201  D23W9W1414    80
# 2  2023    7  2023-07-24     2     9  S54204  B350698202  D23W7W1114    90
# 3  2024    4  2024-04-29     2     9  S57283  B440412302  D24W3W1469    80
# 4  2024    4  2024-04-29     2     9  S57283  B440412201  D24W4W1343    80
#
#   주조구분  ...  압연일자4 압연외경4 압연폭4 최종압연공정     최종압연일자 제품압연작업조        생성일시 HCR 투입중량  \
# 0    T  ...    NaN     0    0   8100 2023-09-21       B  2023-10-05 NaN  NaN
# 1    T  ...    NaN     0    0   8100 2023-09-21       B  2023-10-05 NaN  NaN
# 2    T  ...    NaN     0    0   8100 2023-07-23       B  2023-08-07 NaN  NaN
# 3    T  ...    NaN     0    0   8100 2024-04-28       C  2024-05-03 NaN  NaN
# 4    T  ...    NaN     0    0   8100 2024-04-28       C  2024-05-03 NaN  NaN
#
#   주설비구분
# 0     C
# 1     C
# 2     C
# 3     C
# 4     C
#
# [5 rows x 86 columns]

# %%
# 1,433처럼 중량에 콤마가 있는 Object는 콤마를 제거 후 숫자로 변환해야 함.
Defect_WT['발생중량'] = Defect_WT['발생중량'].str.replace(',', '').astype(int)
#Data_type = Defect_df['발생중량'].dtypes
#print(Data_type)

Defect_WT.head()
# Out:
#     압연년  압연월         년월일  업무구분  공장구분 HEAT_NO      LOT_NO         PON  공정순위  \
# 0  2023    9  2023-09-22     2     9  S54805  B360593201  D23W9W1414    80
# 1  2023    9  2023-09-22     2     9  S54805  B360593201  D23W9W1414    80
# 2  2023    7  2023-07-24     2     9  S54204  B350698202  D23W7W1114    90
# 3  2024    4  2024-04-29     2     9  S57283  B440412302  D24W3W1469    80
# 4  2024    4  2024-04-29     2     9  S57283  B440412201  D24W4W1343    80
#
#   주조구분  ...  압연일자4 압연외경4 압연폭4 최종압연공정     최종압연일자 제품압연작업조        생성일시 HCR 투입중량  \
# 0    T  ...    NaN     0    0   8100 2023-09-21       B  2023-10-05 NaN  NaN
# 1    T  ...    NaN     0    0   8100 2023-09-21       B  2023-10-05 NaN  NaN
# 2    T  ...    NaN     0    0   8100 2023-07-23       B  2023-08-07 NaN  NaN
# 3    T  ...    NaN     0    0   8100 2024-04-28       C  2024-05-03 NaN  NaN
# 4    T  ...    NaN     0    0   8100 2024-04-28       C  2024-05-03 NaN  NaN
#
#   주설비구분
# 0     C
# 1     C
# 2     C
# 3     C
# 4     C
#
# [5 rows x 86 columns]

# %%
# 엑셀 파일로 저장
# pip install openpyxl 사전 설치 필요
output_path = 'pre_defect_316LDSB.xlsx'  # 저장할 파일 경로와 이름
Defect_WT.to_excel(output_path, index=False)  # index=False로 설정하여 인덱스를 엑셀에 포함하지 않음
